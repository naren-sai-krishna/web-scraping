# %%
import requests
from bs4 import BeautifulSoup

# %%
r=requests.get('http://m.cricbuzz.com')
c=r.content

# %%
c
# Out:
# b'<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml"><head><script>var is_redirect = /(maws|uc\\.m|m(2|3|4)|wap|www\\.m|legacy|mobile).cricbuzz.com/i.test(window.top.location);\tif(is_redirect && window.location.hostname != "m.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>body{font-family:"Helvetica Neue",Helvetica,Arial,sans-serif;font-size:14px;line-height:1.42857143;color:#333;background-color:#fff;margin:0}.cb-container{width:auto;padding:0 !important}#top{margin-top:0!important}.cb-list-item{padding:10px 15px;position:relative;display:block;margin-bottom: -1px;background-color : #FFF; border: 1px solid #ddd;}a.cb-list-item{color: #555;}.page-header{padding-bottom:0;padding-left:5px;margin:10px 0} .cbz-div-header{background-color:#4E585F;height:43px} h3{margin:0!important}h4,.h4{font-size: 18px;} .ui-li-heading{color:#113D59;margin-top:10px;font-size:14px;font-weight:700}.ui-header{color:#fff;background:#335a7b;text-align:left;word-wrap:break-w
# ...

# %%
soup=BeautifulSoup(c,'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <script>
#    var is_redirect = /(maws|uc\.m|m(2|3|4)|wap|www\.m|legacy|mobile).cricbuzz.com/i.test(window.top.location);	if(is_redirect && window.location.hostname != "m.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";
#   </script>
#   <style>
# ...

# %%
soup.find_all('div',{'class':'cb-list-item miniscore-data ui-branding-style ui-branding-style-partner e'})
# Out:
# []

# %%
all[11].find_all('span',{'class':'ui-allscores ui-bat-team-scores'})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-65-316b97570148> in <module>()
# ----> 1 all[11].find_all('span',{'class':'ui-allscores ui-bat-team-scores'})
#
# IndexError: list index out of range

# %%
print(all[0].text,'\n',all[1].text)
# Out:
# KKR vs MI
#  DD vs SRH Preview

# %% [markdown]
# -----

# %%
import urllib.request as url
from bs4 import BeautifulSoup

# %%
text1=''
r=url.urlopen('http://www.cricbuzz.com/live-cricket-scorecard/20061/mi-vs-csk-1st-match-indian-premier-league-2018').read()
soup=BeautifulSoup(r,'lxml')
print(soup.title.text)
for i in soup.find_all('div',{'class':'cb-col cb-col-100 cb-ltst-wgt-hdr'}):
    text=text+i.find_all('div',{'class':'cb-col cb-col-100 cb-scrd-itms'})
text[0].text

# %%
soup=BeautifulSoup(c,'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-194a62df1647> in <module>()
# ----> 1 soup=BeautifulSoup(c,'html.parser')
#
# NameError: name 'c' is not defined

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <script>
#    var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);	if(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";
#   </script>
#   <style>
# ...

# %%
print(soup.find_all('div',{'class':'cb-col cb-col-8 text-right'}))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-28a970d059f7> in <module>()
# ----> 1 print(soup.find_all('div',{'class':'cb-col cb-col-8 text-right'}).text())
#
# B:\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
help(list.index)
# Out:
# Help on method_descriptor:
#
# index(...)
#     L.index(value, [start, [stop]]) -> integer -- return first index of value.
#     Raises ValueError if the value is not present.
